# %%
import pyopenephys
import matplotlib.pylab as plt
import numpy as np
import os
# %matplotlib inline

file_name = '/home/alessiob/Documents/Codes/C++/tracking-plugins/Tests/test_sources_multi_2017-12-15_15-04-37'

# %%
file = pyopenephys.File(file_name)
# Out:
# Loading Open-Ephys: reading settings.xml...
# Decoding data from  binary  format
# Tracking Port. NodeId:  100
# Loading Open-Ephys: reading settings.xml...
# Decoding data from  binary  format
# Tracking Port. NodeId:  100
# Loading Open-Ephys: reading settings.xml...
# Decoding data from  binary  format
# Tracking Port. NodeId:  100
# Loading Open-Ephys: reading settings.xml...
# Decoding data from  binary  format
# Tracking Port. NodeId:  100

# %%
tracking = file.experiments[0].recordings[0].tracking

# %%
[plt.plot(tr.x, tr.y) for tr in tracking[8:]]
# Out:
# [[<matplotlib.lines.Line2D at 0x7f1b4deaeef0>],
# ...

# %%
tr = tracking[9]

# %%
anas = file.experiments[0].recordings[0].messages
anas[0].times
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1a6e304bf2b0> in <module>()
# ----> 1 anas = file.experiments[0].recordings[0].messages
#       2 anas[0].times
#
# AttributeError: 'Recording' object has no attribute 'messages'

# %%
plt.plot(anas[0].times, anas[0].signal[0]/np.max(anas[0].signal[0]))
plt.plot(tracking[9].times, tracking[9].x)

# %%
plt.plot(tr.times, tr.x)
